# %%
import numpy as np
import random

# Constants
sound_speed = 340  # m/s
lat_conversion = 111263  # meters per degree of latitude
lon_conversion = 97304   # meters per degree of longitude

# Device locations (longitude, latitude, height)
device_locations = np.array([
    [110.241, 27.204, 824],
    [110.783, 27.456, 727],
    [110.762, 27.785, 742],
    [110.251, 28.025, 850],
    [110.524, 27.617, 786],
    [110.467, 28.081, 678],
    [110.047, 27.521, 575]
])

# Sound arrival times at each device (with added random noise)
def add_random_error(sound_times):
    return sound_times + np.random.normal(0, 0.5, sound_times.shape)

sound_times = np.array([
    [100.767, 164.229, 214.850, 270.065],
    [92.453, 112.220, 169.362, 196.583],
    [75.560, 110.696, 156.936, 188.020],
    [94.653, 141.409, 196.517, 258.985],
    [78.600, 86.216, 118.443, 126.669],
    [67.274, 166.270, 175.482, 266.871],
    [103.738, 163.024, 206.789, 210.306]
])
sound_times_with_error = add_random_error(sound_times)

# Calculate distance between two points using latitude and longitude
def haversine_distance(lon1, lat1, lon2, lat2):
    delta_lon = (lon2 - lon1) * lon_conversion
    delta_lat = (lat2 - lat1) * lat_conversion
    return np.sqrt(delta_lon ** 2 + delta_lat ** 2)

# Calculate the time delay from each device to a potential explosion point using latitude and longitude
def time_delay(device, explosion_point, explosion_time):
    distance = haversine_distance(device[0], device[1], explosion_point[0], explosion_point[1])
    height_diff = abs(device[2] - explosion_point[2])
    total_distance = np.sqrt(distance ** 2 + height_diff ** 2)
    time_diff = total_distance / sound_speed
    return explosion_time + time_diff

# Fitness function: evaluate the total error of the sound arrival times and add penalty for time constraints
def fitness(solution, sound_times):
    explosion_times = solution[:4]
    explosion_positions = solution[4:].reshape((4, 3))
    
    total_error = 0
    penalty = 0

    # Check the conditions for each explosion time
    for i in range(4):
        # Ensure explosion time is greater than zero
        if explosion_times[i] <= 0:
            penalty += 1000  # Large penalty for negative or zero times
        
        # Ensure explosion time is less than the minimum arrival time for each device
        for j in range(7):
            min_arrival_time = np.min(sound_times[j])
            if explosion_times[i] >= min_arrival_time:
                penalty += 1000  # Large penalty for exceeding the minimum arrival time

    # Calculate RMSE for the sound arrival times
    for i in range(7):  # For each device
        for j in range(4):  # For each explosion
            predicted_time = time_delay(device_locations[i], explosion_positions[j], explosion_times[j])
            total_error += (predicted_time - sound_times[i, j]) ** 2  # Squared error
    
    # Add penalty if the time differences between explosions exceed 5 seconds
    for i in range(4):
        for j in range(i + 1, 4):
            if abs(explosion_times[i] - explosion_times[j]) > 5:
                penalty += 1000  # Arbitrary large penalty value for violation

    return np.sqrt(total_error) + penalty  # RMSE with penalty

# Initial population generation
def generate_initial_population(pop_size):
    population = []
    for _ in range(pop_size):
        explosion_times = np.random.uniform(1, 200, 4)  # Random initial times, starting from 1 to ensure positive values
        explosion_positions = np.random.uniform([110.0, 27.0, 500], [111.0, 28.0, 900], (4, 3))  # Random positions in lat/lon/height
        solution = np.concatenate([explosion_times, explosion_positions.flatten()])
        population.append(solution)
    return population

# Evolve population function
def evolve_population(population, elite_size=1, generation_num=1, max_generations=500):
    # Sort population by fitness
    population = sorted(population, key=lambda x: fitness(x, sound_times_with_error))

    # Elite preservation: retain the best solutions
    new_population = population[:elite_size]

    # Adaptive mutation rate
    mutation_rate = max(0.1, 1.0 - (generation_num / max_generations))  # Decaying mutation rate

    # Crossover and mutation
    while len(new_population) < len(population):
        parents = random.sample(population[:len(population) // 2], 2)  # Select from best half
        cross_point = random.randint(1, len(parents[0]) - 1)
        child = np.concatenate([parents[0][:cross_point], parents[1][cross_point:]])

        # Mutation
        if random.random() < mutation_rate:
            mutation_index = random.randint(0, len(child) - 1)
            child[mutation_index] += np.random.uniform(-1, 1)

        new_population.append(child)

    return new_population

# Particle Swarm Optimization
class Particle:
    def __init__(self, dimensions):
        self.position = np.random.uniform(1, 200, dimensions)
        self.velocity = np.random.uniform(-1, 1, dimensions)
        self.best_position = self.position.copy()
        self.best_fitness = float('inf')

def particle_swarm_optimization(best_solution, num_particles=50, max_iterations=1000, w=0.5, c1=1.5, c2=1.5, sound_times_with_error=None):
    dimensions = len(best_solution)
    swarm = [Particle(dimensions) for _ in range(num_particles)]

    global_best_position = best_solution.copy()
    global_best_fitness = fitness(global_best_position, sound_times_with_error)

    for iteration in range(max_iterations):
        for particle in swarm:
            # Update particle's fitness
            particle_fitness = fitness(particle.position, sound_times_with_error)

            # Update personal best
            if particle_fitness < particle.best_fitness:
                particle.best_position = particle.position.copy()
                particle.best_fitness = particle_fitness

            # Update global best
            if particle_fitness < global_best_fitness:
                global_best_position = particle.position.copy()
                global_best_fitness = particle_fitness

        for particle in swarm:
            # Update velocity
            particle.velocity = (
                w * particle.velocity +
                c1 * np.random.rand() * (particle.best_position - particle.position) +
                c2 * np.random.rand() * (global_best_position - particle.position)
            )

            # Update position
            particle.position += particle.velocity

        # Print progress
        if iteration % 100 == 0:
            print(f"Iteration {iteration}, Best fitness: {global_best_fitness}")

    return global_best_position

# Genetic algorithm with elite preservation and PSO
def genetic_algorithm_with_pso(pop_size=300, generations=1000, elite_size=5, sound_times_with_error=None):
    population = generate_initial_population(pop_size)

    for generation in range(generations):
        population = evolve_population(population, elite_size, generation, generations)

        # Track the best solution found
        best_solution = min(population, key=lambda x: fitness(x, sound_times_with_error))
        best_fitness = fitness(best_solution, sound_times_with_error)
        
        print(f"Generation {generation}: Best fitness = {best_fitness}")

        # If fitness is good enough, stop early
        if best_fitness < 100:
            break
    
    # After genetic algorithm finishes, perform PSO for local search
    best_solution = particle_swarm_optimization(best_solution, sound_times_with_error=sound_times_with_error)
    
    return best_solution
    
# Test the model with new synthetic data
def simulate_new_data():
    new_device_locations = np.array([
        [110.500, 27.600, 750],
        [110.600, 27.700, 760],
        [110.700, 27.800, 770],
        [110.800, 27.900, 780],
        [110.900, 28.000, 790],
        [111.000, 28.100, 800],
        [111.100, 28.200, 810]
    ])
    
    # Generate synthetic sound times based on new locations
    new_sound_times = np.random.uniform(50, 250, (7, 4)) + add_random_error(np.zeros((7, 4)))
    
    return new_device_locations, new_sound_times

# Run the optimized genetic algorithm with PSO and error correction
new_device_locations, new_sound_times = simulate_new_data()

best_solution = genetic_algorithm_with_pso(sound_times_with_error=new_sound_times)

# Extract the results
explosion_times = best_solution[:4]
explosion_positions = best_solution[4:].reshape((4, 3))

# Calculate final error
total_error = fitness(best_solution, new_sound_times)

# Output the final explosion times and positions with error
print("Best explosion times:", explosion_times)
print("Best explosion positions (longitude, latitude, height):", explosion_positions)
print("Total error (RMSE):", total_error)
# Out:
# Generation 0: Best fitness = 5385.066652557725
# Generation 1: Best fitness = 5385.066652557725
# Generation 2: Best fitness = 3510.586292950045
# Generation 3: Best fitness = 3479.9970618465104
# Generation 4: Best fitness = 3462.2198682546705
# Generation 5: Best fitness = 3454.2615780120727
# Generation 6: Best fitness = 3364.2184095320627
# Generation 7: Best fitness = 1031.734530872821
# Generation 8: Best fitness = 732.0904578424963
# Generation 9: Best fitness = 451.17827478096626
# Generation 10: Best fitness = 451.17827478096626
# Generation 11: Best fitness = 425.1419869909645
# Generation 12: Best fitness = 351.1345586327126
# Generation 13: Best fitness = 351.3865239521124
# Generation 14: Best fitness = 363.1080777208969
# Generation 15: Best fitness = 321.57715563819215
# Generation 16: Best fitness = 336.6200418533641
# Generation 17: Best fitness = 336.81258286083556
# Generation 18: Best fitness = 336.2669733356283
# Generation 19: Best fitness = 341.4225070722402
# Generation 20: Best fitness = 343.3980904947048
# Generation 21: Best fitness = 346.7200430004417
# Generation 22: Best fitness = 352.51396964959764
# Generation 23: Best fitness = 364.2406709604409
# Generation 24: Best fitness = 355.8491375449531
# Generation 25: Best fitness = 364.88008663855004
# Generation 26: Best fitness = 368.09944335585277
# Generation 27: Best fitness = 364.6183614009325
# Generation 28: Best fitness = 358.88434019378974
# Generation 29: Best fitness = 360.7122929574234
# Generation 30: Best fitness = 366.2730356736341
# Generation 31: Best fitness = 364.83952876094406
# Generation 32: Best fitness = 365.3067626583807
# Generation 33: Best fitness = 374.1142438172254
# Generation 34: Best fitness = 363.8441798908921
# Generation 35: Best fitness = 364.5464900585469
# Generation 36: Best fitness = 362.8568965458708
# Generation 37: Best fitness = 366.20783308715966
# Generation 38: Best fitness = 368.2266231466833
# Generation 39: Best fitness = 362.72072454591546
# Generation 40: Best fitness = 352.10700999441605
# Generation 41: Best fitness = 344.4097890298258
# Generation 42: Best fitness = 358.84032315618055
# Generation 43: Best fitness = 362.12744069512155
# Generation 44: Best fitness = 365.23581761514293
# Generation 45: Best fitness = 356.32510428752187
# Generation 46: Best fitness = 353.16415109010416
# Generation 47: Best fitness = 368.7218340058466
# Generation 48: Best fitness = 361.3323131966006
# Generation 49: Best fitness = 345.0818654745065
# Generation 50: Best fitness = 346.8050778067873
# Generation 51: Best fitness = 340.939057948185
# Generation 52: Best fitness = 354.35515920822155
# Generation 53: Best fitness = 341.9948885766162
# Generation 54: Best fitness = 341.4725026603249
# Generation 55: Best fitness = 349.5898289450198
# Generation 56: Best fitness = 352.6270858672147
# Generation 57: Best fitness = 360.82301557806295
# Generation 58: Best fitness = 338.9959371194095
# Generation 59: Best fitness = 350.9551263681787
# Generation 60: Best fitness = 356.1717621844299
# Generation 61: Best fitness = 349.71572006890716
# Generation 62: Best fitness = 346.9553327947964
# Generation 63: Best fitness = 349.2600439801016
# Generation 64: Best fitness = 343.19500658242015
# Generation 65: Best fitness = 346.0413486088257
# Generation 66: Best fitness = 342.53611727210773
# Generation 67: Best fitness = 345.404729999696
# Generation 68: Best fitness = 345.19843282536283
# Generation 69: Best fitness = 351.68194440655924
# Generation 70: Best fitness = 352.16631114492816
# Generation 71: Best fitness = 346.22616356716816
# Generation 72: Best fitness = 347.4523669737598
# Generation 73: Best fitness = 337.5936795441113
# Generation 74: Best fitness = 351.4719967614348
# Generation 75: Best fitness = 352.0041551173248
# Generation 76: Best fitness = 351.77884558910847
# Generation 77: Best fitness = 356.0795535134659
# Generation 78: Best fitness = 342.6242681918322
# Generation 79: Best fitness = 350.3372333957954
# Generation 80: Best fitness = 350.04084868426435
# Generation 81: Best fitness = 343.2985961330638
# Generation 82: Best fitness = 347.0760846851184
# Generation 83: Best fitness = 345.9260673785683
# Generation 84: Best fitness = 348.09393982130695
# Generation 85: Best fitness = 346.00505122338893
# Generation 86: Best fitness = 352.2401211457169
# Generation 87: Best fitness = 346.6242948899322
# Generation 88: Best fitness = 346.00261024446326
# Generation 89: Best fitness = 354.1080116932011
# Generation 90: Best fitness = 354.2235924222353
# Generation 91: Best fitness = 345.81913076704257
# Generation 92: Best fitness = 347.315890922626
# Generation 93: Best fitness = 348.6178183429144
# Generation 94: Best fitness = 350.43519584776135
# Generation 95: Best fitness = 350.5300316470929
# Generation 96: Best fitness = 355.0258485446745
# Generation 97: Best fitness = 353.27168560266495
# Generation 98: Best fitness = 360.2200797809471
# Generation 99: Best fitness = 354.6858460233339
# Generation 100: Best fitness = 354.8365358543346
# Generation 101: Best fitness = 354.37855531532267
# Generation 102: Best fitness = 349.0452269523144
# Generation 103: Best fitness = 351.2017293111882
# Generation 104: Best fitness = 349.60086198824536
# Generation 105: Best fitness = 349.7886225849711
# Generation 106: Best fitness = 355.83658130139054
# Generation 107: Best fitness = 350.4990803774802
# Generation 108: Best fitness = 355.7950807974268
# Generation 109: Best fitness = 351.57357755083297
# Generation 110: Best fitness = 352.20354511852037
# Generation 111: Best fitness = 355.53831183707706
# Generation 112: Best fitness = 349.63253189116386
# Generation 113: Best fitness = 350.425028795319
# Generation 114: Best fitness = 357.02227280468367
# Generation 115: Best fitness = 350.68526736258565
# Generation 116: Best fitness = 358.9595855358914
# Generation 117: Best fitness = 351.79365147940115
# Generation 118: Best fitness = 352.3675660506648
# Generation 119: Best fitness = 352.9030767845972
# Generation 120: Best fitness = 356.591625543859
# Generation 121: Best fitness = 353.1467194286981
# Generation 122: Best fitness = 353.5347506619979
# Generation 123: Best fitness = 351.0616658772172
# Generation 124: Best fitness = 354.62639589587707
# Generation 125: Best fitness = 351.9058191862084
# Generation 126: Best fitness = 350.41419941140913
# Generation 127: Best fitness = 353.6304475185471
# Generation 128: Best fitness = 354.7957586711157
# Generation 129: Best fitness = 347.9049038284206
# Generation 130: Best fitness = 354.085844875053
# Generation 131: Best fitness = 355.35769598923787
# Generation 132: Best fitness = 352.3305993494534
# Generation 133: Best fitness = 350.45053459202114
# Generation 134: Best fitness = 354.00242574896686
# Generation 135: Best fitness = 352.27802293358747
# Generation 136: Best fitness = 352.6904033545367
# Generation 137: Best fitness = 349.433757493725
# Generation 138: Best fitness = 350.9243331847728
# Generation 139: Best fitness = 350.7190389397486
# Generation 140: Best fitness = 349.37990284503906
# Generation 141: Best fitness = 352.8806198201654
# Generation 142: Best fitness = 352.5194936368409
# Generation 143: Best fitness = 352.95375371506486
# Generation 144: Best fitness = 354.9366455009138
# Generation 145: Best fitness = 352.22676760646857
# Generation 146: Best fitness = 355.1987374459441
# Generation 147: Best fitness = 351.8845328001495
# Generation 148: Best fitness = 352.846597019148
# Generation 149: Best fitness = 349.1744097697772
# Generation 150: Best fitness = 353.10722227744844
# Generation 151: Best fitness = 349.15673252750344
# Generation 152: Best fitness = 347.2218306835314
# Generation 153: Best fitness = 354.10127068273374
# Generation 154: Best fitness = 353.6905551593601
# Generation 155: Best fitness = 353.92808109241025
# Generation 156: Best fitness = 354.15157863349197
# Generation 157: Best fitness = 353.11021132047244
# Generation 158: Best fitness = 352.47600798372116
# Generation 159: Best fitness = 351.6181468262975
# Generation 160: Best fitness = 349.8472707285404
# Generation 161: Best fitness = 351.2546364817221
# Generation 162: Best fitness = 345.36837730349544
# Generation 163: Best fitness = 351.3472365017912
# Generation 164: Best fitness = 356.0565669106491
# Generation 165: Best fitness = 352.40777623506875
# Generation 166: Best fitness = 352.9914579334504
# Generation 167: Best fitness = 351.9182117071939
# Generation 168: Best fitness = 352.4656789773111
# Generation 169: Best fitness = 352.30733705756154
# Generation 170: Best fitness = 351.7275172275591
# Generation 171: Best fitness = 354.0407440126987
# Generation 172: Best fitness = 351.1723522125757
# Generation 173: Best fitness = 351.65303174837027
# Generation 174: Best fitness = 352.5423551854938
# Generation 175: Best fitness = 351.54749957356705
# Generation 176: Best fitness = 350.39597658701206
# Generation 177: Best fitness = 350.4887947012553
# Generation 178: Best fitness = 351.5732456852979
# Generation 179: Best fitness = 352.4858814134274
# Generation 180: Best fitness = 351.11145756605515
# Generation 181: Best fitness = 352.50480816576663
# Generation 182: Best fitness = 351.33636218442666
# Generation 183: Best fitness = 351.82753901224424
# Generation 184: Best fitness = 351.34274714033376
# Generation 185: Best fitness = 353.4293845508792
# Generation 186: Best fitness = 352.49945475717806
# Generation 187: Best fitness = 352.822966403188
# Generation 188: Best fitness = 351.6958464367572
# Generation 189: Best fitness = 350.8493452500456
# Generation 190: Best fitness = 353.61419295409996
# Generation 191: Best fitness = 347.65948986500325
# Generation 192: Best fitness = 353.6228286737595
# Generation 193: Best fitness = 350.49783987719337
# Generation 194: Best fitness = 351.6319537179542
# Generation 195: Best fitness = 351.56734108997455
# Generation 196: Best fitness = 351.8118546429572
# Generation 197: Best fitness = 353.1352409288738
# Generation 198: Best fitness = 350.85966563584464
# Generation 199: Best fitness = 350.5853907599923
# Generation 200: Best fitness = 350.4169140120659
# Generation 201: Best fitness = 350.2529999045148
# Generation 202: Best fitness = 353.00748333733003
# Generation 203: Best fitness = 350.55772722251817
# Generation 204: Best fitness = 350.58642814059647
# Generation 205: Best fitness = 350.19333014800185
# Generation 206: Best fitness = 349.8235483520017
# Generation 207: Best fitness = 350.14639946467133
# Generation 208: Best fitness = 349.36776290732627
# Generation 209: Best fitness = 348.4550669530655
# Generation 210: Best fitness = 352.92791105067226
# Generation 211: Best fitness = 349.70462976710365
# Generation 212: Best fitness = 347.8914895477827
# Generation 213: Best fitness = 350.33115905843107
# Generation 214: Best fitness = 349.3561475429141
# Generation 215: Best fitness = 351.39439010729916
# Generation 216: Best fitness = 351.10224669460433
# Generation 217: Best fitness = 350.2161298121292
# Generation 218: Best fitness = 349.2319703054544
# Generation 219: Best fitness = 349.41887261161787
# Generation 220: Best fitness = 347.0472631514836
# Generation 221: Best fitness = 348.7410301367554
# Generation 222: Best fitness = 351.1055748562677
# Generation 223: Best fitness = 349.19451671407296
# Generation 224: Best fitness = 349.90307862363363
# Generation 225: Best fitness = 349.36867790348373
# Generation 226: Best fitness = 350.65304793846207
# Generation 227: Best fitness = 350.1606920661281
# Generation 228: Best fitness = 350.555133377617
# Generation 229: Best fitness = 350.4154050702059
# Generation 230: Best fitness = 351.9414061671392
# Generation 231: Best fitness = 350.6229593964567
# Generation 232: Best fitness = 350.82960653119466
# Generation 233: Best fitness = 348.46735689653804
# Generation 234: Best fitness = 348.2526389609602
# Generation 235: Best fitness = 350.99927586163295
# Generation 236: Best fitness = 351.64210458494176
# Generation 237: Best fitness = 348.48569688897595
# Generation 238: Best fitness = 350.77377519351415
# Generation 239: Best fitness = 348.9014757127821
# Generation 240: Best fitness = 351.329227330516
# Generation 241: Best fitness = 351.5990979736749
# Generation 242: Best fitness = 350.2072741595677
# Generation 243: Best fitness = 349.6198305212706
# Generation 244: Best fitness = 352.8732530269117
# Generation 245: Best fitness = 351.012138129945
# Generation 246: Best fitness = 350.2083304440356
# Generation 247: Best fitness = 351.24284958798415
# Generation 248: Best fitness = 349.49912316115876
# Generation 249: Best fitness = 351.49383348522724
# Generation 250: Best fitness = 351.2908353319269
# Generation 251: Best fitness = 348.8875989622312
# Generation 252: Best fitness = 350.3489102408296
# Generation 253: Best fitness = 347.7977157920035
# Generation 254: Best fitness = 349.73115432541505
# Generation 255: Best fitness = 351.11893517741566
# Generation 256: Best fitness = 351.0876156305587
# Generation 257: Best fitness = 350.8479466736716
# Generation 258: Best fitness = 351.28389216386114
# Generation 259: Best fitness = 358.9119790688952
# Generation 260: Best fitness = 350.0779161094807
# Generation 261: Best fitness = 349.0698323637519
# Generation 262: Best fitness = 350.29695914843535
# Generation 263: Best fitness = 350.7614868922863
# Generation 264: Best fitness = 351.0737735093379
# Generation 265: Best fitness = 351.471727949419
# Generation 266: Best fitness = 348.18213006350516
# Generation 267: Best fitness = 351.07404150716974
# Generation 268: Best fitness = 350.28499644570496
# Generation 269: Best fitness = 349.20122851888283
# Generation 270: Best fitness = 351.66978166097783
# Generation 271: Best fitness = 351.75207400426547
# Generation 272: Best fitness = 349.8053668696061
# Generation 273: Best fitness = 348.85921230197033
# Generation 274: Best fitness = 349.95504864590066
# Generation 275: Best fitness = 348.9129924079918
# Generation 276: Best fitness = 348.5231060196616
# Generation 277: Best fitness = 351.579529995078
# Generation 278: Best fitness = 354.02236463877915
# Generation 279: Best fitness = 349.58376297827476
# Generation 280: Best fitness = 350.63005422098433
# Generation 281: Best fitness = 350.2514593298316
# Generation 282: Best fitness = 349.91085290852357
# Generation 283: Best fitness = 349.04889488496974
# Generation 284: Best fitness = 348.2028346258202
# Generation 285: Best fitness = 350.0379713242715
# Generation 286: Best fitness = 351.89392325444635
# Generation 287: Best fitness = 350.3723638503934
# Generation 288: Best fitness = 348.98488723799653
# Generation 289: Best fitness = 348.6046933210686
# Generation 290: Best fitness = 350.87602114064765
# Generation 291: Best fitness = 349.4853216674337
# Generation 292: Best fitness = 349.8432529254529
# Generation 293: Best fitness = 348.7599957536362
# Generation 294: Best fitness = 349.2906683480568
# Generation 295: Best fitness = 349.71151914017486
# Generation 296: Best fitness = 351.750886943025
# Generation 297: Best fitness = 348.52336226228584
# Generation 298: Best fitness = 349.1230192448225
# Generation 299: Best fitness = 351.4003615678085
# Generation 300: Best fitness = 348.5683934713581
# Generation 301: Best fitness = 353.2878676183643
# Generation 302: Best fitness = 349.1033902621637
# Generation 303: Best fitness = 348.9946350462327
# Generation 304: Best fitness = 348.3704423996566
# Generation 305: Best fitness = 361.23457770849126
# Generation 306: Best fitness = 349.2107344846374
# Generation 307: Best fitness = 348.9680809761867
# Generation 308: Best fitness = 350.8553560541438
# Generation 309: Best fitness = 348.3666935221971
# Generation 310: Best fitness = 351.75265808197514
# Generation 311: Best fitness = 349.5667544690911
# Generation 312: Best fitness = 348.2497562220853
# Generation 313: Best fitness = 348.87001001353246
# Generation 314: Best fitness = 349.3233681018924
# Generation 315: Best fitness = 351.8073027495312
# Generation 316: Best fitness = 348.96400902660093
# Generation 317: Best fitness = 349.0043802211674
# Generation 318: Best fitness = 348.24660410917045
# Generation 319: Best fitness = 350.6308400170297
# Generation 320: Best fitness = 350.0313175174184
# Generation 321: Best fitness = 348.1963748314303
# Generation 322: Best fitness = 350.93250431183213
# Generation 323: Best fitness = 350.2394774532781
# Generation 324: Best fitness = 349.23317081691454
# Generation 325: Best fitness = 350.17594618750735
# Generation 326: Best fitness = 349.59041521362565
# Generation 327: Best fitness = 354.30775868763277
# Generation 328: Best fitness = 351.4093009903109
# Generation 329: Best fitness = 351.5467766015936
# Generation 330: Best fitness = 348.49284704418784
# Generation 331: Best fitness = 350.4742752458002
# Generation 332: Best fitness = 350.6622787858867
# Generation 333: Best fitness = 355.865722592431
# Generation 334: Best fitness = 350.09909756614286
# Generation 335: Best fitness = 350.13591549934455
# Generation 336: Best fitness = 350.7927162113714
# Generation 337: Best fitness = 348.6897025532193
# Generation 338: Best fitness = 349.28389030589364
# Generation 339: Best fitness = 349.5022689109812
# Generation 340: Best fitness = 348.4987606652321
# Generation 341: Best fitness = 350.0541402621635
# Generation 342: Best fitness = 349.7451412293565
# Generation 343: Best fitness = 349.04510898201033
# Generation 344: Best fitness = 348.76456395911447
# Generation 345: Best fitness = 349.56942363146584
# Generation 346: Best fitness = 348.49185580738737
# Generation 347: Best fitness = 349.28218181537204
# Generation 348: Best fitness = 348.44643896631885
# Generation 349: Best fitness = 348.63268079704346
# Generation 350: Best fitness = 349.4993405182255
# Generation 351: Best fitness = 348.69219916315893
# Generation 352: Best fitness = 348.7160116712787
# Generation 353: Best fitness = 348.95984333311355
# Generation 354: Best fitness = 347.83108425219876
# Generation 355: Best fitness = 350.4248260504819
# Generation 356: Best fitness = 349.03608051951136
# Generation 357: Best fitness = 357.52520580088014
# Generation 358: Best fitness = 348.8728079865899
# Generation 359: Best fitness = 347.87847434070454
# Generation 360: Best fitness = 349.4470746668572
# Generation 361: Best fitness = 348.35073314777554
# Generation 362: Best fitness = 348.48358251123847
# Generation 363: Best fitness = 348.96317015076954
# Generation 364: Best fitness = 348.7338610196888
# Generation 365: Best fitness = 349.362347125833
# Generation 366: Best fitness = 348.36807939560555
# Generation 367: Best fitness = 371.35775103188075
# Generation 368: Best fitness = 348.2544358904502
# Generation 369: Best fitness = 348.7831016077071
# Generation 370: Best fitness = 348.22146713540985
# Generation 371: Best fitness = 348.7765628475956
# Generation 372: Best fitness = 348.4511024299719
# Generation 373: Best fitness = 349.99098207922066
# Generation 374: Best fitness = 348.9816300774342
# Generation 375: Best fitness = 348.8137624235267
# Generation 376: Best fitness = 360.2187731440154
# Generation 377: Best fitness = 349.5791039776623
# Generation 378: Best fitness = 348.25258160204584
# Generation 379: Best fitness = 349.7559019598208
# Generation 380: Best fitness = 348.37538891217105
# Generation 381: Best fitness = 348.7771408228803
# Generation 382: Best fitness = 348.6748158988511
# Generation 383: Best fitness = 348.8829872414185
# Generation 384: Best fitness = 348.89966590637266
# Generation 385: Best fitness = 349.1879972767549
# Generation 386: Best fitness = 348.6980750760939
# Generation 387: Best fitness = 349.93911959848185
# Generation 388: Best fitness = 351.24274851387503
# Generation 389: Best fitness = 348.86379109566127
# Generation 390: Best fitness = 355.9824451762988
# Generation 391: Best fitness = 352.6902903975141
# Generation 392: Best fitness = 349.1164105772897
# Generation 393: Best fitness = 349.8640966495742
# Generation 394: Best fitness = 348.7496498263603
# Generation 395: Best fitness = 348.74710838329236
# Generation 396: Best fitness = 348.73108221782127
# Generation 397: Best fitness = 348.70188825743924
# Generation 398: Best fitness = 348.3480110177395
# Generation 399: Best fitness = 348.62955906366574
# Generation 400: Best fitness = 349.5422654921519
# Generation 401: Best fitness = 349.33481376587525
# Generation 402: Best fitness = 348.5789421525982
# Generation 403: Best fitness = 348.45953170317193
# Generation 404: Best fitness = 365.00268350278475
# Generation 405: Best fitness = 349.2677291098769
# Generation 406: Best fitness = 348.48547524462333
# Generation 407: Best fitness = 348.7214564104686
# Generation 408: Best fitness = 350.2523893365548
# Generation 409: Best fitness = 350.0984849121888
# Generation 410: Best fitness = 348.29255483527675
# Generation 411: Best fitness = 348.4986965721677
# Generation 412: Best fitness = 348.75806287542025
# Generation 413: Best fitness = 349.0353934014771
# Generation 414: Best fitness = 349.21199180940704
# Generation 415: Best fitness = 350.0151089169985
# Generation 416: Best fitness = 348.70481388748055
# Generation 417: Best fitness = 350.2568889562138
# Generation 418: Best fitness = 361.0075212597637
# Generation 419: Best fitness = 348.5232595084085
# Generation 420: Best fitness = 350.1613352995914
# Generation 421: Best fitness = 349.2372037468385
# Generation 422: Best fitness = 349.0001960769724
# Generation 423: Best fitness = 348.8996674359074
# Generation 424: Best fitness = 348.9436664530304
# Generation 425: Best fitness = 363.2363528180051
# Generation 426: Best fitness = 349.04089407857236
# Generation 427: Best fitness = 348.6170196637622
# Generation 428: Best fitness = 348.33114300909244
# Generation 429: Best fitness = 349.9291498100344
# Generation 430: Best fitness = 349.27366554158294
# Generation 431: Best fitness = 349.02219595449185
# Generation 432: Best fitness = 349.86002810158965
# Generation 433: Best fitness = 349.6697637580584
# Generation 434: Best fitness = 349.8820137012463
# Generation 435: Best fitness = 348.40513552783943
# Generation 436: Best fitness = 348.9319696754995
# Generation 437: Best fitness = 349.4837806643232
# Generation 438: Best fitness = 349.6197506794228
# Generation 439: Best fitness = 349.8936491808327
# Generation 440: Best fitness = 349.2783042694293
# Generation 441: Best fitness = 348.65904587832233
# Generation 442: Best fitness = 349.48991969919814
# Generation 443: Best fitness = 349.1169679677964
# Generation 444: Best fitness = 348.47506020946116
# Generation 445: Best fitness = 349.84672114957067
# Generation 446: Best fitness = 350.2911733396377
# Generation 447: Best fitness = 349.4737568014036
# Generation 448: Best fitness = 348.6900481050017
# Generation 449: Best fitness = 349.0018390871088
# Generation 450: Best fitness = 350.24921457336666
# Generation 451: Best fitness = 348.8077865505924
# Generation 452: Best fitness = 348.43564625194017
# Generation 453: Best fitness = 349.00943852120645
# Generation 454: Best fitness = 348.6489462633811
# Generation 455: Best fitness = 348.44160421260926
# Generation 456: Best fitness = 349.1877066567962
# Generation 457: Best fitness = 349.1289778083167
# Generation 458: Best fitness = 348.4354857961153
# Generation 459: Best fitness = 350.7727332686752
# Generation 460: Best fitness = 351.00407064917505
# Generation 461: Best fitness = 350.44998463635676
# Generation 462: Best fitness = 349.00239833237873
# Generation 463: Best fitness = 348.43389602425054
# Generation 464: Best fitness = 352.09535096812556
# Generation 465: Best fitness = 348.94615184821527
# Generation 466: Best fitness = 349.91834242768067
# Generation 467: Best fitness = 349.46093647696676
# Generation 468: Best fitness = 349.42257275921264
# Generation 469: Best fitness = 361.682861674242
# Generation 470: Best fitness = 350.665721032347
# Generation 471: Best fitness = 348.8129811941901
# Generation 472: Best fitness = 348.59430616465534
# Generation 473: Best fitness = 349.15348738533226
# Generation 474: Best fitness = 365.67229323207977
# Generation 475: Best fitness = 348.4422392244435
# Generation 476: Best fitness = 349.6030162248168
# Generation 477: Best fitness = 348.93312332338917
# Generation 478: Best fitness = 349.0054871223117
# Generation 479: Best fitness = 349.3878235554233
# Generation 480: Best fitness = 355.3310980907079
# Generation 481: Best fitness = 348.94299851132786
# Generation 482: Best fitness = 349.0623190967857
# Generation 483: Best fitness = 352.7066459175804
# Generation 484: Best fitness = 348.62839139524783
# Generation 485: Best fitness = 348.9581275577274
# Generation 486: Best fitness = 348.52446343891523
# Generation 487: Best fitness = 348.5334836249419
# Generation 488: Best fitness = 361.1423852448328
# Generation 489: Best fitness = 348.9405849176764
# Generation 490: Best fitness = 348.4272078599174
# Generation 491: Best fitness = 348.4457935821209
# Generation 492: Best fitness = 357.44795730133785
# Generation 493: Best fitness = 349.6276175055747
# Generation 494: Best fitness = 349.2224507952587
# Generation 495: Best fitness = 350.0907296407515
# Generation 496: Best fitness = 348.96661234012305
# Generation 497: Best fitness = 357.38525715113485
# Generation 498: Best fitness = 353.2460463476182
# Generation 499: Best fitness = 349.0375139625586
# Generation 500: Best fitness = 350.1090247190726
# Generation 501: Best fitness = 348.601667973404
# Generation 502: Best fitness = 349.26645965955146
# Generation 503: Best fitness = 348.96426068233296
# Generation 504: Best fitness = 348.9660659911606
# Generation 505: Best fitness = 348.79374203120364
# Generation 506: Best fitness = 350.05591371741485
# Generation 507: Best fitness = 348.59915438956983
# Generation 508: Best fitness = 349.57259590973064
# Generation 509: Best fitness = 348.77432582791147
# Generation 510: Best fitness = 349.1335361913672
# Generation 511: Best fitness = 348.75365952584826
# Generation 512: Best fitness = 349.21395336629666
# Generation 513: Best fitness = 351.62697944224504
# Generation 514: Best fitness = 348.47071977880404
# Generation 515: Best fitness = 348.4338167430619
# Generation 516: Best fitness = 350.9546120059094
# Generation 517: Best fitness = 349.0038447141478
# Generation 518: Best fitness = 350.09488691430977
# Generation 519: Best fitness = 349.83565315933316
# Generation 520: Best fitness = 349.9299722522971
# Generation 521: Best fitness = 349.97166384670504
# Generation 522: Best fitness = 349.4275003577255
# Generation 523: Best fitness = 349.91652807898214
# Generation 524: Best fitness = 348.9504550274519
# Generation 525: Best fitness = 351.2298805813641
# Generation 526: Best fitness = 348.5758332037428
# Generation 527: Best fitness = 350.175216224346
# Generation 528: Best fitness = 349.82946036629517
# Generation 529: Best fitness = 350.3546965700899
# Generation 530: Best fitness = 349.031633853591
# Generation 531: Best fitness = 348.50493228928804
# Generation 532: Best fitness = 348.79749991126994
# Generation 533: Best fitness = 348.9963379953572
# Generation 534: Best fitness = 361.515999372049
# Generation 535: Best fitness = 349.18861857084386
# Generation 536: Best fitness = 351.41516884581705
# Generation 537: Best fitness = 349.08225727553287
# Generation 538: Best fitness = 349.5699449913197
# Generation 539: Best fitness = 349.0463008396587
# Generation 540: Best fitness = 349.2903098567876
# Generation 541: Best fitness = 373.6782340353078
# Generation 542: Best fitness = 349.2969917620442
# Generation 543: Best fitness = 348.98712761728467
# Generation 544: Best fitness = 360.6101766992586
# Generation 545: Best fitness = 348.9844383133678
# Generation 546: Best fitness = 349.6517146610741
# Generation 547: Best fitness = 348.53314962285225
# Generation 548: Best fitness = 351.4456144917121
# Generation 549: Best fitness = 349.1613413242328
# Generation 550: Best fitness = 348.99687791229036
# Generation 551: Best fitness = 348.44639188294525
# Generation 552: Best fitness = 348.9464311257594
# Generation 553: Best fitness = 349.10683668761527
# Generation 554: Best fitness = 349.1247854889064
# Generation 555: Best fitness = 350.0462765632907
# Generation 556: Best fitness = 349.24959204788445
# Generation 557: Best fitness = 348.9577793496177
# Generation 558: Best fitness = 362.2036750218911
# Generation 559: Best fitness = 351.33124775932646
# Generation 560: Best fitness = 360.78185824414294
# Generation 561: Best fitness = 348.4931999970323
# Generation 562: Best fitness = 349.1209815623726
# Generation 563: Best fitness = 349.2064657971185
# Generation 564: Best fitness = 349.6259241928051
# Generation 565: Best fitness = 348.9183295458712
# Generation 566: Best fitness = 356.68408923085684
# Generation 567: Best fitness = 350.63110605089804
# Generation 568: Best fitness = 348.9528356807239
# Generation 569: Best fitness = 360.82491142922095
# Generation 570: Best fitness = 349.4004966704428
# Generation 571: Best fitness = 349.80859656679604
# Generation 572: Best fitness = 360.08799378359015
# Generation 573: Best fitness = 350.1995109804305
# Generation 574: Best fitness = 350.6684573557204
# Generation 575: Best fitness = 355.90728352784953
# Generation 576: Best fitness = 348.72077868109204
# Generation 577: Best fitness = 348.9559728545357
# Generation 578: Best fitness = 348.53683644548687
# Generation 579: Best fitness = 349.93268697332593
# Generation 580: Best fitness = 352.5263234516012
# Generation 581: Best fitness = 351.0553118634336
# Generation 582: Best fitness = 350.1236373614357
# Generation 583: Best fitness = 350.86564615123126
# Generation 584: Best fitness = 359.11299270314686
# Generation 585: Best fitness = 349.31939560919284
# Generation 586: Best fitness = 349.74894153780036
# Generation 587: Best fitness = 350.2339769698628
# Generation 588: Best fitness = 348.44466747095737
# Generation 589: Best fitness = 350.2073192342626
# Generation 590: Best fitness = 349.4054115095338
# Generation 591: Best fitness = 349.1999917204535
# Generation 592: Best fitness = 349.39642558564736
# Generation 593: Best fitness = 348.68803672329614
# Generation 594: Best fitness = 364.04918323378274
# Generation 595: Best fitness = 349.82448829925926
# Generation 596: Best fitness = 373.1339110147556
# Generation 597: Best fitness = 349.27297765880326
# Generation 598: Best fitness = 349.41073209131133
# Generation 599: Best fitness = 349.77127495702894
# Generation 600: Best fitness = 349.1390437981141
# Generation 601: Best fitness = 349.5302136026458
# Generation 602: Best fitness = 350.11575780648514
# Generation 603: Best fitness = 349.28381339280116
# Generation 604: Best fitness = 360.9980605866251
# Generation 605: Best fitness = 350.6630839448532
# Generation 606: Best fitness = 350.51213398265526
# Generation 607: Best fitness = 348.58414488092023
# Generation 608: Best fitness = 356.5911539456401
# Generation 609: Best fitness = 361.8281420863046
# Generation 610: Best fitness = 348.53383538533245
# Generation 611: Best fitness = 350.347740407576
# Generation 612: Best fitness = 351.88059568238947
# Generation 613: Best fitness = 366.69587361062054
# Generation 614: Best fitness = 350.10309817028667
# Generation 615: Best fitness = 362.068033866473
# Generation 616: Best fitness = 349.98238522251717
# Generation 617: Best fitness = 350.0258493190372
# Generation 618: Best fitness = 358.41276001504065
# Generation 619: Best fitness = 350.9303250492
# Generation 620: Best fitness = 349.61495944059476
# Generation 621: Best fitness = 348.482985359254
# Generation 622: Best fitness = 349.8305197449242
# Generation 623: Best fitness = 348.5677969434253
# Generation 624: Best fitness = 349.3745575757622
# Generation 625: Best fitness = 353.3364720787359
# Generation 626: Best fitness = 348.9996376239597
# Generation 627: Best fitness = 349.68741029324156
# Generation 628: Best fitness = 349.019904151704
# Generation 629: Best fitness = 348.5454975605081
# Generation 630: Best fitness = 359.0725837000324
# Generation 631: Best fitness = 349.9585820310324
# Generation 632: Best fitness = 356.07670174077384
# Generation 633: Best fitness = 348.9741829210039
# Generation 634: Best fitness = 360.0624095296488
# Generation 635: Best fitness = 349.7634102661399
# Generation 636: Best fitness = 350.3981164988201
# Generation 637: Best fitness = 350.04995926769936
# Generation 638: Best fitness = 350.1163161020461
# Generation 639: Best fitness = 361.2639658260456
# Generation 640: Best fitness = 365.1757901223915
# Generation 641: Best fitness = 360.88263397417273
# Generation 642: Best fitness = 349.0583057106615
# Generation 643: Best fitness = 356.16340141226766
# Generation 644: Best fitness = 348.43413856548034
# Generation 645: Best fitness = 351.0233054871945
# Generation 646: Best fitness = 348.6723831139162
# Generation 647: Best fitness = 349.2408279471426
# Generation 648: Best fitness = 349.5941348787467
# Generation 649: Best fitness = 349.4941914400631
# Generation 650: Best fitness = 350.5482013912072
# Generation 651: Best fitness = 349.0642333022597
# Generation 652: Best fitness = 349.72617041530833
# Generation 653: Best fitness = 348.95146693969076
# Generation 654: Best fitness = 348.4583282458002
# Generation 655: Best fitness = 350.0813794735691
# Generation 656: Best fitness = 348.890201924393
# Generation 657: Best fitness = 350.18199264529073
# Generation 658: Best fitness = 350.0540038339439
# Generation 659: Best fitness = 360.94710565378375
# Generation 660: Best fitness = 349.10575406620364
# Generation 661: Best fitness = 350.2922226463445
# Generation 662: Best fitness = 348.9876361332403
# Generation 663: Best fitness = 354.7321426205482
# Generation 664: Best fitness = 349.07049556925585
# Generation 665: Best fitness = 367.3958602893604
# Generation 666: Best fitness = 351.10581738053276
# Generation 667: Best fitness = 350.0272218589473
# Generation 668: Best fitness = 348.5052911546819
# Generation 669: Best fitness = 349.60027440278606
# Generation 670: Best fitness = 349.2354232633883
# Generation 671: Best fitness = 350.17653835583843
# Generation 672: Best fitness = 353.57203541040144
# Generation 673: Best fitness = 355.9232504340977
# Generation 674: Best fitness = 355.7454712601138
# Generation 675: Best fitness = 356.34600551814617
# Generation 676: Best fitness = 349.63342620155777
# Generation 677: Best fitness = 349.0340034118827
# Generation 678: Best fitness = 349.93599542300785
# Generation 679: Best fitness = 349.158171368049
# Generation 680: Best fitness = 350.71058836150803
# Generation 681: Best fitness = 349.159387990352
# Generation 682: Best fitness = 348.54680556922614
# Generation 683: Best fitness = 350.2129355635313
# Generation 684: Best fitness = 349.34237796334224
# Generation 685: Best fitness = 362.018124631756
# Generation 686: Best fitness = 349.3347402326928
# Generation 687: Best fitness = 349.9400551722865
# Generation 688: Best fitness = 349.81845281468935
# Generation 689: Best fitness = 348.49472764241585
# Generation 690: Best fitness = 350.37941610192553
# Generation 691: Best fitness = 348.5675092512764
# Generation 692: Best fitness = 358.2095460068398
# Generation 693: Best fitness = 363.39569671693357
# Generation 694: Best fitness = 356.8590252926693
# Generation 695: Best fitness = 348.74070810739636
# Generation 696: Best fitness = 374.95270750094556
# Generation 697: Best fitness = 349.99132653616834
# Generation 698: Best fitness = 348.48887330053236
# Generation 699: Best fitness = 348.52085400760456
# Generation 700: Best fitness = 348.9767115648869
# Generation 701: Best fitness = 355.7110747648845
# Generation 702: Best fitness = 349.15360720473427
# Generation 703: Best fitness = 353.45668462106823
# Generation 704: Best fitness = 349.8306163731091
# Generation 705: Best fitness = 349.6916174049119
# Generation 706: Best fitness = 351.761782175802
# Generation 707: Best fitness = 370.9950797729591
# Generation 708: Best fitness = 348.9852210355882
# Generation 709: Best fitness = 349.3635950242153
# Generation 710: Best fitness = 349.7265150825191
# Generation 711: Best fitness = 363.36445532480104
# Generation 712: Best fitness = 349.04210098824325
# Generation 713: Best fitness = 348.9866001175947
# Generation 714: Best fitness = 360.8100553577637
# Generation 715: Best fitness = 351.7493382469201
# Generation 716: Best fitness = 349.3796366174345
# Generation 717: Best fitness = 348.9294452626469
# Generation 718: Best fitness = 349.9163578068782
# Generation 719: Best fitness = 376.2290862685301
# Generation 720: Best fitness = 353.3354916302267
# Generation 721: Best fitness = 353.18437774036454
# Generation 722: Best fitness = 348.55331385845017
# Generation 723: Best fitness = 348.50153014267465
# Generation 724: Best fitness = 348.4579442077205
# Generation 725: Best fitness = 356.8543481684929
# Generation 726: Best fitness = 350.3685113817934
# Generation 727: Best fitness = 361.8863394907735
# Generation 728: Best fitness = 350.03940932873525
# Generation 729: Best fitness = 356.1940815034347
# Generation 730: Best fitness = 350.1426745129458
# Generation 731: Best fitness = 349.0921542046252
# Generation 732: Best fitness = 348.97083708792394
# Generation 733: Best fitness = 356.1499930475869
# Generation 734: Best fitness = 357.7787808727417
# Generation 735: Best fitness = 357.0256960620627
# Generation 736: Best fitness = 348.449579619629
# Generation 737: Best fitness = 349.20966001527864
# Generation 738: Best fitness = 376.25281601049085
# Generation 739: Best fitness = 378.7796059953903
# Generation 740: Best fitness = 349.20485066452295
# Generation 741: Best fitness = 349.4144221833594
# Generation 742: Best fitness = 355.48967457775433
# Generation 743: Best fitness = 354.4522089732233
# Generation 744: Best fitness = 361.3898127525381
# Generation 745: Best fitness = 349.7781102887948
# Generation 746: Best fitness = 349.9553809059369
# Generation 747: Best fitness = 356.3575344504358
# Generation 748: Best fitness = 350.3452622069644
# Generation 749: Best fitness = 364.441589421751
# Generation 750: Best fitness = 352.2065200657888
# Generation 751: Best fitness = 351.4886059828398
# Generation 752: Best fitness = 348.83467089477193
# Generation 753: Best fitness = 360.8497242690886
# Generation 754: Best fitness = 371.884550239165
# Generation 755: Best fitness = 361.4874535225375
# Generation 756: Best fitness = 373.8334488525437
# Generation 757: Best fitness = 348.6195016420052
# Generation 758: Best fitness = 353.11837187533143
# Generation 759: Best fitness = 349.25325960517245
# Generation 760: Best fitness = 349.4694772447188
# Generation 761: Best fitness = 364.22186857568795
# Generation 762: Best fitness = 349.1082037826572
# Generation 763: Best fitness = 349.38817570056176
# Generation 764: Best fitness = 363.3595053043399
# Generation 765: Best fitness = 364.2686042265706
# Generation 766: Best fitness = 350.70957685566526
# Generation 767: Best fitness = 349.06886174187474
# Generation 768: Best fitness = 369.00375100607073
# Generation 769: Best fitness = 349.3761975478841
# Generation 770: Best fitness = 348.60465945824603
# Generation 771: Best fitness = 349.3574657703716
# Generation 772: Best fitness = 368.5811056953548
# Generation 773: Best fitness = 361.9512742202505
# Generation 774: Best fitness = 356.44166223595585
# Generation 775: Best fitness = 349.0056579241065
# Generation 776: Best fitness = 360.6964972481371
# Generation 777: Best fitness = 349.1034880225136
# Generation 778: Best fitness = 363.420222477826
# Generation 779: Best fitness = 349.02311838419064
# Generation 780: Best fitness = 356.4225074090559
# Generation 781: Best fitness = 366.7963317093878
# Generation 782: Best fitness = 349.04083712464757
# Generation 783: Best fitness = 350.3442480605705
# Generation 784: Best fitness = 375.673492717762
# Generation 785: Best fitness = 350.0242718356065
# Generation 786: Best fitness = 357.5584944932228
# Generation 787: Best fitness = 356.38555860769566
# Generation 788: Best fitness = 350.6912242901937
# Generation 789: Best fitness = 364.1898061542483
# Generation 790: Best fitness = 349.15494498000174
# Generation 791: Best fitness = 362.85124464110845
# Generation 792: Best fitness = 349.8499426329038
# Generation 793: Best fitness = 361.11652428717264
# Generation 794: Best fitness = 349.5339222203087
# Generation 795: Best fitness = 356.32687430658376
# Generation 796: Best fitness = 348.49209510075127
# Generation 797: Best fitness = 349.5618309647928
# Generation 798: Best fitness = 349.62600325060396
# Generation 799: Best fitness = 361.91518485149567
# Generation 800: Best fitness = 352.2242917215301
# Generation 801: Best fitness = 349.0521063710449
# Generation 802: Best fitness = 356.69749642293215
# Generation 803: Best fitness = 349.00887918317517
# Generation 804: Best fitness = 357.3308993430998
# Generation 805: Best fitness = 350.4125111006738
# Generation 806: Best fitness = 349.24347052513025
# Generation 807: Best fitness = 372.8536469850543
# Generation 808: Best fitness = 377.4244260543321
# Generation 809: Best fitness = 350.9577068467409
# Generation 810: Best fitness = 348.9055303023325
# Generation 811: Best fitness = 368.7306595235511
# Generation 812: Best fitness = 350.0413740580503
# Generation 813: Best fitness = 349.0865629921282
# Generation 814: Best fitness = 360.7940123841882
# Generation 815: Best fitness = 349.73887396871146
# Generation 816: Best fitness = 349.0048550446622
# Generation 817: Best fitness = 366.81646032514135
# Generation 818: Best fitness = 365.0139751871425
# Generation 819: Best fitness = 349.3917377273313
# Generation 820: Best fitness = 348.6772344685733
# Generation 821: Best fitness = 350.290985431713
# Generation 822: Best fitness = 350.23307588957096
# Generation 823: Best fitness = 353.08910579381785
# Generation 824: Best fitness = 372.3112421031117
# Generation 825: Best fitness = 376.0849205331564
# Generation 826: Best fitness = 373.0632714609513
# Generation 827: Best fitness = 378.22501748871196
# Generation 828: Best fitness = 350.2133129957985
# Generation 829: Best fitness = 352.48233991570413
# Generation 830: Best fitness = 369.06202494853
# Generation 831: Best fitness = 356.11602093354355
# Generation 832: Best fitness = 352.6706830265072
# Generation 833: Best fitness = 360.9537855705073
# Generation 834: Best fitness = 369.1035142880452
# Generation 835: Best fitness = 349.7378161093039
# Generation 836: Best fitness = 352.38062387634017
# Generation 837: Best fitness = 349.3857536419026
# Generation 838: Best fitness = 349.7441052583019
# Generation 839: Best fitness = 350.4168429302468
# Generation 840: Best fitness = 374.42206373327724
# Generation 841: Best fitness = 362.86162590968576
# Generation 842: Best fitness = 373.30080310510436
# Generation 843: Best fitness = 350.40443117978214
# Generation 844: Best fitness = 359.02054607719805
# Generation 845: Best fitness = 362.2774742730081
# Generation 846: Best fitness = 378.30663417837354
# Generation 847: Best fitness = 349.5441594969388
# Generation 848: Best fitness = 352.6330593830107
# Generation 849: Best fitness = 349.68106936554994
# Generation 850: Best fitness = 348.48475503469
# Generation 851: Best fitness = 349.771596364445
# Generation 852: Best fitness = 360.05881033929177
# Generation 853: Best fitness = 367.35359304298265
# Generation 854: Best fitness = 350.0372499340882
# Generation 855: Best fitness = 349.03630413820764
# Generation 856: Best fitness = 360.7466187568273
# Generation 857: Best fitness = 362.7885987534674
# Generation 858: Best fitness = 348.6331156909813
# Generation 859: Best fitness = 351.8218241139968
# Generation 860: Best fitness = 348.9333649351987
# Generation 861: Best fitness = 378.46074072710627
# Generation 862: Best fitness = 351.9742332911116
# Generation 863: Best fitness = 378.7395338298896
# Generation 864: Best fitness = 372.1501062615061
# Generation 865: Best fitness = 349.01520902877803
# Generation 866: Best fitness = 349.0616564081685
# Generation 867: Best fitness = 349.07809996492017
# Generation 868: Best fitness = 362.97468328237744
# Generation 869: Best fitness = 378.3230002564169
# Generation 870: Best fitness = 361.4342635103647
# Generation 871: Best fitness = 362.5803431859226
# Generation 872: Best fitness = 364.90593877281094
# Generation 873: Best fitness = 350.39889661169394
# Generation 874: Best fitness = 372.5207062754497
# Generation 875: Best fitness = 348.73891125109793
# Generation 876: Best fitness = 356.69170745089576
# Generation 877: Best fitness = 355.08674437224687
# Generation 878: Best fitness = 370.5930992427717
# Generation 879: Best fitness = 349.21539819846373
# Generation 880: Best fitness = 349.2770990446798
# Generation 881: Best fitness = 358.9883079453205
# Generation 882: Best fitness = 349.0951636728804
# Generation 883: Best fitness = 368.57614690392796
# Generation 884: Best fitness = 367.08682605914754
# Generation 885: Best fitness = 366.5646582807452
# Generation 886: Best fitness = 349.2880745626055
# Generation 887: Best fitness = 368.84526222657894
# Generation 888: Best fitness = 364.0216543723835
# Generation 889: Best fitness = 350.1257848845955
# Generation 890: Best fitness = 352.34060274716944
# Generation 891: Best fitness = 348.96988508359505
# Generation 892: Best fitness = 378.4096345756248
# Generation 893: Best fitness = 374.05319282917367
# Generation 894: Best fitness = 349.0914091066927
# Generation 895: Best fitness = 358.82888095102675
# Generation 896: Best fitness = 378.8953633066248
# Generation 897: Best fitness = 350.911855596218
# Generation 898: Best fitness = 349.13462022096746
# Generation 899: Best fitness = 348.5100219845428
# Generation 900: Best fitness = 358.05901890015195
# Generation 901: Best fitness = 378.37944317915543
# Generation 902: Best fitness = 349.5983502032928
# Generation 903: Best fitness = 349.088885224284
# Generation 904: Best fitness = 348.52464129961567
# Generation 905: Best fitness = 348.5705533747101
# Generation 906: Best fitness = 359.6651256447713
# Generation 907: Best fitness = 370.3369523248096
# Generation 908: Best fitness = 370.62108593487625
# Generation 909: Best fitness = 349.5744632376161
# Generation 910: Best fitness = 348.49065986805874
# Generation 911: Best fitness = 360.79939535967634
# Generation 912: Best fitness = 376.1386271805546
# Generation 913: Best fitness = 378.5225988323759
# Generation 914: Best fitness = 355.0338794091692
# Generation 915: Best fitness = 350.37592774384206
# Generation 916: Best fitness = 355.11731450080805
# Generation 917: Best fitness = 378.78154569999026
# Generation 918: Best fitness = 378.76596570235165
# Generation 919: Best fitness = 371.27411440444916
# Generation 920: Best fitness = 371.3669641785376
# Generation 921: Best fitness = 357.60869339373727
# Generation 922: Best fitness = 348.5235043823898
# Generation 923: Best fitness = 365.05603775924754
# Generation 924: Best fitness = 360.6838230736515
# Generation 925: Best fitness = 378.1734470911805
# Generation 926: Best fitness = 349.47705757652096
# Generation 927: Best fitness = 359.99821923587876
# Generation 928: Best fitness = 364.2999541456585
# Generation 929: Best fitness = 351.7890895863317
# Generation 930: Best fitness = 371.9474134835659
# Generation 931: Best fitness = 354.1594741845368
# Generation 932: Best fitness = 362.5516499196079
# Generation 933: Best fitness = 350.32400366548524
# Generation 934: Best fitness = 349.10177171225996
# Generation 935: Best fitness = 374.4427223085409
# Generation 936: Best fitness = 352.1475278804875
# Generation 937: Best fitness = 368.1269241487912
# Generation 938: Best fitness = 369.85154422250736
# Generation 939: Best fitness = 375.0781527684312
# Generation 940: Best fitness = 348.67456472209466
# Generation 941: Best fitness = 351.91041491502506
# Generation 942: Best fitness = 372.67153601740614
# Generation 943: Best fitness = 348.60328318595873
# Generation 944: Best fitness = 364.67719143715476
# Generation 945: Best fitness = 366.5477708686749
# Generation 946: Best fitness = 353.9947318514383
# Generation 947: Best fitness = 368.68955677002276
# Generation 948: Best fitness = 354.1105370448875
# Generation 949: Best fitness = 351.82523990161275
# Generation 950: Best fitness = 349.28211609264457
# Generation 951: Best fitness = 378.5143086911998
# Generation 952: Best fitness = 355.8242146708249
# Generation 953: Best fitness = 349.84808773854326
# Generation 954: Best fitness = 378.28057170071673
# Generation 955: Best fitness = 348.51379206984325
# Generation 956: Best fitness = 348.9209621441582
# Generation 957: Best fitness = 349.8570085383365
# Generation 958: Best fitness = 366.6692672954551
# Generation 959: Best fitness = 356.99003620703456
# Generation 960: Best fitness = 354.0058967651743
# Generation 961: Best fitness = 349.3195204316078
# Generation 962: Best fitness = 367.2034084457766
# Generation 963: Best fitness = 357.13882227056996
# Generation 964: Best fitness = 348.8729307240869
# Generation 965: Best fitness = 363.1515559713224
# Generation 966: Best fitness = 367.02272209064085
# Generation 967: Best fitness = 353.6164593801391
# Generation 968: Best fitness = 349.1201874469142
# Generation 969: Best fitness = 360.7227425713808
# Generation 970: Best fitness = 349.7562571088051
# Generation 971: Best fitness = 372.31282824147155
# Generation 972: Best fitness = 352.6461199023048
# Generation 973: Best fitness = 349.4729233380157
# Generation 974: Best fitness = 351.44848969846
# Generation 975: Best fitness = 349.03606958698765
# Generation 976: Best fitness = 378.63715116406007
# Generation 977: Best fitness = 354.40485318809294
# Generation 978: Best fitness = 378.3070206500614
# Generation 979: Best fitness = 348.4943987032094
# Generation 980: Best fitness = 378.583140283973
# Generation 981: Best fitness = 350.18256659180014
# Generation 982: Best fitness = 369.0791636114946
# Generation 983: Best fitness = 378.2661755390222
# Generation 984: Best fitness = 374.07261526475133
# Generation 985: Best fitness = 350.35046905241325
# Generation 986: Best fitness = 358.4677271531441
# Generation 987: Best fitness = 363.8252716863283
# Generation 988: Best fitness = 355.39700294355987
# Generation 989: Best fitness = 351.4224054495463
# Generation 990: Best fitness = 348.4938269454036
# Generation 991: Best fitness = 363.89234368449377
# Generation 992: Best fitness = 363.5171950921416
# Generation 993: Best fitness = 350.40280796149636
# Generation 994: Best fitness = 349.1506126372641
# Generation 995: Best fitness = 358.37465866312573
# Generation 996: Best fitness = 350.2125748547557
# Generation 997: Best fitness = 349.9775180166989
# Generation 998: Best fitness = 349.21335260494874
# Generation 999: Best fitness = 351.18655141234365
# Iteration 0, Best fitness: 351.18655141234365
# Iteration 100, Best fitness: 276.62010063803643
# Iteration 200, Best fitness: 276.6198465939114
# Iteration 300, Best fitness: 276.61980389906006
# Iteration 400, Best fitness: 276.61980296479453
# Iteration 500, Best fitness: 276.619802950381
# Iteration 600, Best fitness: 276.61980294384404
# Iteration 700, Best fitness: 276.61980293959635
# Iteration 800, Best fitness: 276.6198029392237
# Iteration 900, Best fitness: 276.61980293558815
# Best explosion times: [11.97872243 16.97330964 16.38970079 16.7949202 ]
# Best explosion positions (longitude, latitude, height): [[110.24881132  27.71875567 830.17912749]
#  [110.34201478  27.76222241 782.72874308]
#  [110.41989654  27.70311125 495.09025456]
#  [110.51613294  27.9112601  797.64233002]]
# Total error (RMSE): 276.61980292605904

# %%
pip install pykalman
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pykalman
#   Downloading pykalman-0.9.7-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from pykalman) (1.26.4)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from pykalman) (1.13.1)
# Downloading pykalman-0.9.7-py2.py3-none-any.whl (251 kB)
#    ---------------------------------------- 0.0/251.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/251.6 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/251.6 kB 330.3 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/251.6 kB 330.3 kB/s eta 0:00:01
#    ----------- --------------------------- 71.7/251.6 kB 393.8 kB/s eta 0:00:01
#    -------------------- ----------------- 133.1/251.6 kB 605.3 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/251.6 kB 695.5 kB/s eta 0:00:01
#    -------------------------------------- 251.6/251.6 kB 858.8 kB/s eta 0:00:00
# Installing collected packages: pykalman
# Successfully installed pykalman-0.9.7
# Note: you may need to restart the kernel to use updated packages.

# %%
#使用卡尔曼滤波进行0.5s的噪音处理
import numpy as np
import random
from pykalman import KalmanFilter

# Constants
sound_speed = 340  # m/s
lat_conversion = 111263  # meters per degree of latitude
lon_conversion = 97304   # meters per degree of longitude

# Device locations (longitude, latitude, height)
device_locations = np.array([
    [110.241, 27.204, 824],
    [110.783, 27.456, 727],
    [110.762, 27.785, 742],
    [110.251, 28.025, 850],
    [110.524, 27.617, 786],
    [110.467, 28.081, 678],
    [110.047, 27.521, 575]
])

# Sound arrival times with random noise added
def add_random_error(sound_times):
    return sound_times + np.random.normal(0, 0.5, sound_times.shape)

sound_times = np.array([
    [100.767, 164.229, 214.850, 270.065],
    [92.453, 112.220, 169.362, 196.583],
    [75.560, 110.696, 156.936, 188.020],
    [94.653, 141.409, 196.517, 258.985],
    [78.600, 86.216, 118.443, 126.669],
    [67.274, 166.270, 175.482, 266.871],
    [103.738, 163.024, 206.789, 210.306]
])
sound_times_with_error = add_random_error(sound_times)

# Calculate distance between two points using latitude and longitude
def haversine_distance(lon1, lat1, lon2, lat2):
    delta_lon = (lon2 - lon1) * lon_conversion
    delta_lat = (lat2 - lat1) * lat_conversion
    return np.sqrt(delta_lon ** 2 + delta_lat ** 2)

# Apply Kalman filter to correct noisy sound times
def apply_kalman_filter(sound_times_with_error):
    kf = KalmanFilter(initial_state_mean=np.zeros(sound_times_with_error.shape[1]), n_dim_obs=sound_times_with_error.shape[1])
    kf = kf.em(sound_times_with_error, n_iter=10)
    filtered_state_means, _ = kf.filter(sound_times_with_error)

    # Ensure the output shape is compatible
    if len(filtered_state_means.shape) == 1:
        filtered_state_means = filtered_state_means.reshape(-1, 1)
    
    return filtered_state_means

# Fitness function with multiple sampling and Kalman filter for noise reduction
def fitness_with_sampling_kalman(solution, sound_times, num_samples=10):
    explosion_times = solution[:4]
    explosion_positions = solution[4:].reshape((4, 3))
    
    total_error = 0
    penalty = 0

    # Kalman filter application to sound times
    filtered_sound_times = apply_kalman_filter(sound_times)

    # Run multiple samples to average out the error due to noise
    for _ in range(num_samples):
        sampled_sound_times = add_random_error(filtered_sound_times)  # Add noise to filtered sound times

        # Check the conditions for each explosion time
        for i in range(4):
            if explosion_times[i] <= 0:
                penalty += 1000  # Large penalty for negative or zero times

            for j in range(7):
                min_arrival_time = np.min(sampled_sound_times[j])
                if explosion_times[i] >= min_arrival_time:
                    penalty += 1000  # Large penalty for exceeding the minimum arrival time

        # Calculate RMSE for the sound arrival times
        for i in range(7):  # For each device
            for j in range(4):  # For each explosion
                predicted_time = time_delay(device_locations[i], explosion_positions[j], explosion_times[j])
                total_error += (predicted_time - sampled_sound_times[i, j]) ** 2  # Squared error

    # Normalize the total error by the number of samples to get the average
    total_error = total_error / num_samples
    
    # Add penalty if the time differences between explosions exceed 5 seconds
    for i in range(4):
        for j in range(i + 1, 4):
            if abs(explosion_times[i] - explosion_times[j]) > 5:
                penalty += 1000  # Arbitrary large penalty value for violation

    return np.sqrt(total_error) + penalty  # RMSE with penalty

# The rest of the algorithm remains unchanged, including PSO and genetic algorithm integration

# Generate initial population, run optimization, etc.
def generate_initial_population(pop_size):
    population = []
    for _ in range(pop_size):
        explosion_times = np.random.uniform(1, 200, 4)  # Random initial times, starting from 1 to ensure positive values
        explosion_positions = np.random.uniform([110.0, 27.0, 500], [111.0, 28.0, 900], (4, 3))  # Random positions in lat/lon/height
        solution = np.concatenate([explosion_times, explosion_positions.flatten()])
        population.append(solution)
    return population

# Evolve population function
def evolve_population(population, elite_size=1, generation_num=1, max_generations=500):
    # Sort population by fitness
    population = sorted(population, key=lambda x: fitness_with_sampling_kalman(x, sound_times_with_error))

    # Elite preservation: retain the best solutions
    new_population = population[:elite_size]

    # Adaptive mutation rate
    mutation_rate = max(0.1, 1.0 - (generation_num / max_generations))  # Decaying mutation rate

    # Crossover and mutation
    while len(new_population) < len(population):
        parents = random.sample(population[:len(population) // 2], 2)  # Select from best half
        cross_point = random.randint(1, len(parents[0]) - 1)
        child = np.concatenate([parents[0][:cross_point], parents[1][cross_point:]])

        # Mutation
        if random.random() < mutation_rate:
            mutation_index = random.randint(0, len(child) - 1)
            child[mutation_index] += np.random.uniform(-1, 1)

        new_population.append(child)

    return new_population

# Particle Swarm Optimization
class Particle:
    def __init__(self, dimensions):
        self.position = np.random.uniform(1, 200, dimensions)
        self.velocity = np.random.uniform(-1, 1, dimensions)
        self.best_position = self.position.copy()
        self.best_fitness = float('inf')

def particle_swarm_optimization(best_solution, num_particles=50, max_iterations=1000, w=0.5, c1=1.5, c2=1.5):
    dimensions = len(best_solution)
    swarm = [Particle(dimensions) for _ in range(num_particles)]

    global_best_position = best_solution.copy()
    global_best_fitness = fitness_with_sampling_kalman(global_best_position, sound_times_with_error)

    for iteration in range(max_iterations):
        for particle in swarm:
            # Update particle's fitness
            particle_fitness = fitness_with_sampling_kalman(particle.position, sound_times_with_error)

            # Update personal best
            if particle_fitness < particle.best_fitness:
                particle.best_position = particle.position.copy()
                particle.best_fitness = particle_fitness

            # Update global best
            if particle_fitness < global_best_fitness:
                global_best_position = particle.position.copy()
                global_best_fitness = particle_fitness

        for particle in swarm:
            # Update velocity
            particle.velocity = (
                w * particle.velocity +
                c1 * np.random.rand() * (particle.best_position - particle.position) +
                c2 * np.random.rand() * (global_best_position - particle.position)
            )

            # Update position
            particle.position += particle.velocity

        # Print progress
        if iteration % 100 == 0:
            print(f"Iteration {iteration}, Best fitness: {global_best_fitness}")

    return global_best_position

# Genetic algorithm with elite preservation and PSO
def genetic_algorithm_with_pso(pop_size=300, generations=1000, elite_size=5):
    population = generate_initial_population(pop_size)

    for generation in range(generations):
        population = evolve_population(population, elite_size, generation, generations)

        # Track the best solution found
        best_solution = min(population, key=lambda x: fitness_with_sampling_kalman(x, sound_times_with_error))
        best_fitness = fitness_with_sampling_kalman(best_solution, sound_times_with_error)
        
        print(f"Generation {generation}: Best fitness = {best_fitness}")

        # If fitness is good enough, stop early
        if best_fitness < 100:
            break
    
    # After genetic algorithm finishes, perform PSO for local search
    best_solution = particle_swarm_optimization(best_solution)
    
    return best_solution

# Test the model with new synthetic data
def simulate_new_data():
    new_device_locations = np.array([
        [110.500, 27.600, 750],
        [110.600, 27.700, 760],
        [110.700, 27.800, 770],
        [110.800, 27.900, 780],
        [110.900, 28.000, 790],
        [111.000, 28.100, 800],
        [111.100, 28.200, 810]
    ])
    
    # Generate synthetic sound times based on new locations
    new_sound_times = np.random.uniform(50, 250, (7, 4)) + add_random_error(np.zeros((7, 4)))
    
    return new_device_locations, new_sound_times

# Run the optimized genetic algorithm with PSO and error correction
new_device_locations, new_sound_times = simulate_new_data()

best_solution = genetic_algorithm_with_pso()

# Extract the results
explosion_times = best_solution[:4]
explosion_positions = best_solution[4:].reshape((4, 3))

# Calculate final error
total_error = fitness_with_sampling_kalman(best_solution, new_sound_times)

# Output the final explosion times and positions with error
print("Best explosion times:", explosion_times)
print("Best explosion positions (longitude, latitude, height):", explosion_positions)
print("Total error (RMSE):", total_error)
